# %% [markdown]
# # Library Setup

# %%
import getpass
from datetime import date, datetime, timedelta
import Utility
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e90c22e4-ba76-4ae5-abfd-c83e21964cfd">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# # Utility Parameters

# %%
valMailUsername = getpass.getpass('Please enter your email account name:')
valMailPW = getpass.getpass('Please enter the password for that account:')
# Out:
# Please enter your email account name: ······················
# Please enter the password for that account: ·········

# %%
valDateFilter = datetime(2018,10,23)
print(valDateFilter)
fileName = "./docs/index.html"
# Out:
# 2018-10-23 00:00:00

# %% [markdown]
# # Produce Plot
# ## Component Build

# %%
# %%time
dfTmp = Utility.getData(valDateFilter,valMailUsername,valMailPW,numCut=150)
print(dfTmp.shape)
# Out:
# (17, 6)
# CPU times: user 1.13 s, sys: 123 ms, total: 1.25 s
# Wall time: 1min 15s

# %%
# %%time
plotBoat,dfLocs = Utility.getPlot(fileName,dfTmp)
# Out:
# /anaconda/envs/Env_IQT/lib/python3.5/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /anaconda/envs/Env_IQT/lib/python3.5/site-packages/bokeh/plotting/helpers.py:290: UserWarning: HoverTool are being repeated
#   warnings.warn("%s are being repeated" % ",".join(repeated_tools))
# CPU times: user 393 ms, sys: 8.15 ms, total: 402 ms
# Wall time: 2.46 s

# %% [markdown]
# ## All-at-Once Build

# %%
# %%time
plotBoat,dfLocs = Utility.runOnceGetData(fileName,valDateFilter,valMailUsername,valMailPW)
